# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel("netflix1.xlsx")
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df.shape
# Out:
# (8790, 10)

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df.tail()
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#                date_added  release_year rating   duration  \
# 8785            1/17/2017          2016  TV-PG  2 Seasons
# 8786            9/13/2018          2016  TV-Y7  3 Seasons
# 8787           12/15/2016          2012  TV-PG   1 Season
# 8788            6/23/2018          2016   TV-Y   1 Season
# 8789  2018-07-06 00:00:00          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# ...

# %%
print(df.isnull().sum())
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
print(df.describe())
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
catcol=df.columns
catcol
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
for column in catcol:
    print(f"Column: {column}")
    print(f"Unique values in {column}: {df[column].unique()}\n")
# Out:
# Column: show_id
# Unique values in show_id: ['s1' 's3' 's6' ... 's8801' 's8784' 's8786']
#
# Column: type
# Unique values in type: ['Movie' 'TV Show']
#
# Column: title
# Unique values in title: ['Dick Johnson Is Dead' 'Ganglands' 'Midnight Mass' ...
#  'Zindagi Gulzar Hai' 'Yoko' 'YOM']
#
# Column: director
# Unique values in director: ['Kirsten Johnson' 'Julien Leclercq' 'Mike Flanagan' ... 'Majid Al Ansari'
#  'Peter Hewitt' 'Mozez Singh']
#
# Column: country
# Unique values in country: ['United States' 'France' 'Brazil' 'United Kingdom' 'India' 'Germany'
#  'Pakistan' 'Not Given' 'China' 'South Africa' 'Japan' 'Nigeria' 'Spain'
#  'Philippines' 'Australia' 'Argentina' 'Canada' 'Hong Kong' 'Italy'
#  'New Zealand' 'Egypt' 'Colombia' 'Mexico' 'Belgium' 'Switzerland'
#  'Taiwan' 'Bulgaria' 'Poland' 'South Korea' 'Saudi Arabia' 'Thailand'
#  'Indonesia' 'Kuwait' 'Malaysia' 'Vietnam' 'Lebanon' 'Romania' 'Syria'
#  'United Arab Emirates' 'Sweden' 'Mauritius' 'Austria' 'Turkey'
# ...

# %%
print(f'Number of duplicated data: {df.duplicated().sum()}')
# Out:
# Number of duplicated data: 0

# %%
df.isnull().sum()  /  len(df)  *  100
# Out:
# show_id         0.0
# type            0.0
# title           0.0
# director        0.0
# country         0.0
# date_added      0.0
# release_year    0.0
# rating          0.0
# duration        0.0
# listed_in       0.0
# dtype: float64

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
freq = df['type'].value_counts()

fig, axes = plt.subplots(1, 2, figsize=(10, 5))

sns.countplot(x='type', data=df, ax=axes[0])
axes[0].set_title('Count of Content Types')

axes[1].pie(freq, labels=freq.index, autopct='%.0f%%', startangle=90)
axes[1].set_title('Percentage of Content Types')

plt.suptitle('Total Content on Netflix', fontsize=20)

plt.tight_layout()
plt.show()

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'TV-PG', 'TV-14', 'TV-Y7', 'TV-Y', 'PG', 'TV-G',
#        'R', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [raw]
# PG-13: Parental Guidance suggested for children under 13. May contain material inappropriate for young children.
#
# TV-MA: TV Mature Audience. Specifically for adults and unsuitable for children under
# 17. May contain strong language, violence, or explicit content.
#
# TV-PG: Parental Guidance suggested. Some material may be unsuitable for younger children.
#
# TV-14: Parents strongly cautioned. Some material may be inappropriate for children under
#
# TV-Y7: Suitable for children age 7 and older. May contain mild fantasy violence or themes.
#
# TV-Y: Suitable for all children. Specifically designed for a young audience, including children aged 2-6.
#
# PG: Parental Guidance suggested. Some material may not be suitable for children.
#
# TV-G: General audience. Suitable for all ages, with little or no content that would offend parents.
#
# R: Restricted. Requires an accompanying adult for viewers under 17 due to strong content.
#
# G: General audience. Suitable for all ages.
#
# NC-17: No one under 17 admitted. Contains explicit content not suitable for children.
#
# NR: Not Rated. The show or movie has not been assigned a formal rating.
#
# TV-Y7-FV: Similar to TV-Y7 but with "Fantasy Violence," indicating more intense animated violence.
#
# UR: Unrated. Content that has not gone through a formal rating process.

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %%
ratings=df['rating'].value_counts().reset_index().sort_values(by='count',ascending=False)
ratings
# Out:
#       rating  count
# 0      TV-MA   3205
# 1      TV-14   2157
# 2      TV-PG    861
# 3          R    799
# 4      PG-13    490
# 5      TV-Y7    333
# 6       TV-Y    306
# 7         PG    287
# 8       TV-G    220
# 9         NR     79
# 10         G     41
# 11  TV-Y7-FV      6
# 12     NC-17      3
# 13        UR      3

# %%
ratings=df['rating'].value_counts().reset_index().sort_values(by='count',ascending=False)
plt.bar(ratings['rating'], ratings['count'])
plt.xticks(rotation=45)
plt.xlabel("Rating Types")
plt.ylabel("Rating Frequency")
plt.suptitle('Rating on Netflix', fontsize=20)
# Out:
# Text(0.5, 0.98, 'Rating on Netflix')

# %% [markdown]
# # Top 5 Rating on Netflix

# %%
ratings['count']
# Out:
# 0     3205
# 1     2157
# 2      861
# 3      799
# 4      490
# 5      333
# 6      306
# 7      287
# 8      220
# 9       79
# 10      41
# 11       6
# 12       3
# 13       3
# Name: count, dtype: int64

# %%
plt.pie(ratings['count'][:8], labels=ratings['rating'][:8], autopct='%.0f%%')
plt.suptitle('Rating on Netflix', fontsize=20)
# Out:
# Text(0.5, 0.98, 'Rating on Netflix')

# %% [markdown]
# ### Top 10 countries with most content on Netflix

# %%
top_ten_countries=df['country'].value_counts().reset_index().sort_values(by='count', ascending=False)
top_ten_countries
# Out:
#            country  count
# 0    United States   3240
# 1            India   1057
# 2   United Kingdom    638
# 3         Pakistan    421
# 4        Not Given    287
# ..             ...    ...
# 71     Puerto Rico      1
# 70          Cyprus      1
# 69         Somalia      1
# 68        Paraguay      1
# 85    Soviet Union      1
#
# [86 rows x 2 columns]

# %%
top_ten_countries.head(10)
# Out:
#           country  count
# 0   United States   3240
# 1           India   1057
# 2  United Kingdom    638
# 3        Pakistan    421
# 4       Not Given    287
# 5          Canada    271
# 6           Japan    259
# 7     South Korea    214
# 8          France    213
# 9           Spain    182

# %%
top_ten_countries=df['country'].value_counts().reset_index().sort_values(by='count', ascending=False).head(10)
plt.figure(figsize=(10, 6))
plt.bar(top_ten_countries['country'], top_ten_countries['count'])
plt.xticks(rotation=90)
plt.xlabel("Country")
plt.ylabel("Frequency")
plt.suptitle("Top 10 countries with most content on Netflix")
plt.show()

# %% [markdown]
# # distribution of movie durations

# %%
df.head(3)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
# 2      s6  TV Show         Midnight Mass    Mike Flanagan  United States
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
# 2  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %% [markdown]
# # duration

# %%
df['duration'].unique()
# Out:
# array(['90 min', '1 Season', '91 min', '125 min', '9 Seasons', '104 min',
#        '87 min', '127 min', '76 min', '71 min', '131 min', '39 min',
#        '36 min', '34 min', '35 min', '46 min', '67 min', '65 min',
#        '61 min', '166 min', '103 min', '97 min', '106 min', '2 Seasons',
#        '4 Seasons', '147 min', '94 min', '161 min', '111 min', '110 min',
#        '105 min', '96 min', '124 min', '116 min', '98 min', '115 min',
#        '122 min', '55 min', '99 min', '88 min', '100 min', '6 Seasons',
#        '3 Seasons', '23 min', '102 min', '93 min', '95 min', '85 min',
#        '83 min', '182 min', '5 Seasons', '92 min', '84 min', '48 min',
#        '145 min', '119 min', '80 min', '128 min', '143 min', '273 min',
#        '117 min', '114 min', '118 min', '108 min', '37 min', '121 min',
#        '63 min', '142 min', '113 min', '154 min', '120 min', '82 min',
#        '109 min', '101 min', '86 min', '77 min', '229 min', '15 min',
# ...

# %% [raw]
# To analyze this column (which seems to represent durations and seasons of content), you can break down the analysis into two parts:
#
# Movies/Shows with duration in minutes (e.g., 90 min', '125 min')
#
# TV Shows with seasons (e.g., 1 Season', '9 Seasons')
#
# 1. Split the column into two categories:
#
# Entries that contain min (which indicate durations in minutes)
#
# Entries that contain Season(s) (which indicate the number of seasons)
#
# 2. Convert the duration values (in minutes) to integers so that we can perform numerical analysis (like average, minimum, and maximum).
#
# 3. Count the frequency of the number of seasons.

# %%
durations = df['duration'].to_numpy()
durations
# Out:
# array(['90 min', '1 Season', '1 Season', ..., '1 Season', '1 Season',
#        '1 Season'], dtype=object)

# %%
len(durations)
# Out:
# 8790

# %%
# Convert to a pandas DataFrame
df_durations = pd.DataFrame(durations, columns=['duration'])
df_durations
# Out:
#        duration
# 0        90 min
# 1      1 Season
# 2      1 Season
# 3        91 min
# 4       125 min
# ...         ...
# 8785  2 Seasons
# 8786  3 Seasons
# 8787   1 Season
# 8788   1 Season
# 8789   1 Season
#
# [8790 rows x 1 columns]

# %%
df.head(3)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
# 2      s6  TV Show         Midnight Mass    Mike Flanagan  United States
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
# 2  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries

# %%
# Separate durations in minutes and seasons
df_minutes = df_durations[df_durations['duration'].str.contains('min')]
df_seasons = df_durations[df_durations['duration'].str.contains('Season')]

# %%
df_minutes.head()
# Out:
#   duration
# 0   90 min
# 3   91 min
# 4  125 min
# 6  104 min
# 7   87 min

# %%
df_seasons.head()
# Out:
#      duration
# 1    1 Season
# 2    1 Season
# 5   9 Seasons
# 17   1 Season
# 18   1 Season

# %%
# Convert 'min' entries to integers for analysis
df_minutes['duration'] = df_minutes['duration'].str.replace(' min', '').astype(int)

# %%
df_minutes['duration'].unique()
# Out:
# array([ 90,  91, 125, 104,  87, 127,  76,  71, 131,  39,  36,  34,  35,
#         46,  67,  65,  61, 166, 103,  97, 106, 147,  94, 161, 111, 110,
#        105,  96, 124, 116,  98, 115, 122,  55,  99,  88, 100,  23, 102,
#         93,  95,  85,  83, 182,  92,  84,  48, 145, 119,  80, 128, 143,
#        273, 117, 114, 118, 108,  37, 121,  63, 142, 113, 154, 120,  82,
#        109, 101,  86,  77, 229,  15,  89, 156, 112, 107, 129,  44,  68,
#        135, 136, 165, 150, 133,  47,  70,  56,  58,  78, 140,  64,  59,
#         60,  69,  19,  22, 148, 189,  54, 141, 130,  81, 138, 132, 123,
#         66,  62,  74,  38,  13, 139, 126, 155, 159,  12, 137,  49,  72,
#        204,  25, 212,  73, 149, 224, 162,  75,  79,  32, 158, 164, 173,
#        181, 185,  21,  24,  51, 151,  42, 134, 177,  52,  53,   8,  57,
#         28,  50,   9,  26,  45, 171,  27,  33,  29, 146,  20, 157, 203,
#         41,  30,  17, 194, 233, 230, 237, 195, 253, 152, 190, 160, 208,
# ...

# %%
df_minutes.head()
# Out:
#    duration
# 0        90
# 3        91
# 4       125
# 6       104
# 7        87

# %%
# Convert 'Season' entries to integers for analysis
df_seasons['duration'] = df_seasons['duration'].str.extract('(\d+)').astype(int)

# %%
df_seasons.head()
# Out:
#     duration
# 1          1
# 2          1
# 5          9
# 17         1
# 18         1

# %%
df_seasons['duration'].unique()
# Out:
# array([ 1,  9,  2,  4,  6,  3,  5,  7,  8, 15, 10, 17, 13, 12, 11])

# %% [raw]
# df_seasons['duration']: Accesses the 'duration' column from the DataFrame df_seasons. This column likely contains text-based durations (e.g.,"1 Season","2 Seasons").
#
# str.extract('(\d+)'):
#
# The .str accessor is used to apply string functions to each element in the 'duration' column.
#
# extract('(\d+)') is a regular expression (regex) function that looks for digits (\d+) in the string.
#
# \d matches any digit.
# + means "one or more occurrences of the preceding element" (digits in this case).
#
# The parentheses () create a capture group, extracting only the digits from the text. For example, from "2 Seasons", it would extract 2.
# .astype(int):
#
# Converts the extracted digits, which are currently strings, into integers.
# After extraction, the result might be ['1', '2', '3'], which is then converted into integers: [1, 2, 3].
#
# Summary:
# This code extracts the number (digit) from the 'duration' column (which likely contains strings like "1 Season", "2 Seasons"), and converts those numbers to integers. So, for each row, the text-based duration is turned into a numeric format.
#
# Example:
#
# Before: "2 Seasons", "1 Season"
#
# After: 2, 1

# %%
# Analyze the 'minutes' column
print("Statistics for durations in minutes:")
df_minutes['duration'].describe()
# Out:
# Statistics for durations in minutes:
# count    6126.000000
# mean       99.584884
# std        28.283225
# min         3.000000
# 25%        87.000000
# 50%        98.000000
# 75%       114.000000
# max       312.000000
# Name: duration, dtype: float64

# %%
print("\nStatistics for number of seasons:")
df_seasons['duration'].describe()
# Out:
# Statistics for number of seasons:
# count    2664.000000
# mean        1.751877
# std         1.550622
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max        17.000000
# Name: duration, dtype: float64

# %% [markdown]
# # distribution of movie durations

# %%
# Plot distribution of movie durations
plt.figure(figsize=(10, 6))
sns.histplot(df_minutes['duration'], bins=20)
plt.title('Distribution of Content Durations (in minutes)')
plt.xlabel('Duration (minutes)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Distribution of Duration of Seasons

# %%
sns.histplot(df_seasons['duration'], bins=10) 
plt.title('Distribution of Duration of Seasons')
plt.show()

# %%
# Create a figure with multiple subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plot count plot in the first subplot
sns.countplot(x='duration', data=df_seasons, ax=axes[0]) 
axes[0].set_title('Count of Number of Seasons')
axes[0].set_xlabel('Number of Seasons') 
axes[0].set_ylabel('Count') 

# Plot histogram in the second subplot
sns.distplot(df_seasons['duration'], kde=True, ax=axes[1])
axes[1].set_title('Displot of Number of Seasons') 
axes[1].set_xlabel('Number of Seasons')
axes[1].set_ylabel('Density') 

# Show the plot 
plt.tight_layout()
plt.show()

# %%
df_seasons ['duration'].value_counts()
# Out:
# duration
# 1     1791
# 2      421
# 3      198
# 4       94
# 5       64
# 6       33
# 7       23
# 8       17
# 9        9
# 10       6
# 15       2
# 13       2
# 12       2
# 17       1
# 11       1
# Name: count, dtype: int64

# %%
df_seasons['duration'].value_counts()
# Out:
# duration
# 1     1791
# 2      421
# 3      198
# 4       94
# 5       64
# 6       33
# 7       23
# 8       17
# 9        9
# 10       6
# 15       2
# 13       2
# 12       2
# 17       1
# 11       1
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.countplot(x='duration', data=df_seasons, ax=axes[0])
axes[0].set_title('Count of Number of Seasons')
axes[0].set_xlabel('Number of Seasons')
axes[0].set_ylabel('Count')

season_counts = df_minutes['duration'].value_counts().head(30)
axes[1].bar(season_counts.index, season_counts.values, color='skyblue')
axes[1].set_title('Top 30 Duration Counts')
axes[1].set_xlabel('Duration (Minutes)')
axes[1].set_ylabel('Count')
axes[1].tick_params(axis='x', rotation=45)  # Rotate the x-axis labels for better readability

# Show the plot
plt.tight_layout()
plt.show()

# %%
plt.pie(ratings['count'][:8], labels=ratings['rating'][:8], autopct='%.0f%%')
plt.show()

# %% [markdown]
# # Count of Movies vs TV Shows

# %%
#Count the number of Movies and TV Shows:

#Count the number of Movies and TV Shows:
type_counts =df['type'].value_counts() 
plt.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%') 
plt.title('Proportion of Movies vs TV Shows') 
plt.show()

# %% [markdown]
# # Release Year Distribution

# %%
#PLot the distribution of release years
sns.distplot(df['release_year'])
plt.title('Distribution of Release Year')
plt.xlabel('Year') 
plt.ylabel('Count') 
plt.show()

# %% [markdown]
# # Explore how Movies and TV Shows are distributed by country:

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %% [markdown]
# # Distribution of Ratings

# %%
sns.countplot(x='rating', data=df)
plt.xticks(rotation=45)
plt.title('Distribution of Content Ratings')
plt.show()

# %%
#Analyze the distribution of content ratings:

sns.countplot(x='rating', data=df, order=df['rating'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Distribution of Content Ratings')
plt.show()

# %% [markdown]
# # Release Year Distribution

# %%
#Plot the distribution of release years

sns.distplot(df['release_year'])
plt.title('Distribution of Release Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Explore how Movies and TV Shows are distributed by country:

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
top_countries = df['country'].value_counts().head(10).index
top_countries
# Out:
# Index(['United States', 'India', 'United Kingdom', 'Pakistan', 'Not Given',
#        'Canada', 'Japan', 'South Korea', 'France', 'Spain'],
#       dtype='object', name='country')

# %% [raw]
# The isin(top_countries) checks if the values in country are part of a predefined list called top_countries (e.g., the top 10 countries).

# %%
top_countries = df['country'].value_counts().head(10).index

# Filter the dataframe to include only the top 10 countries
sns.countplot(x='country', hue='type', data=df[df['country'].isin(top_countries)])
plt.title('Type of Content by Top 10 Countries')
plt.xticks(rotation=90)
plt.show()

# %%
#Rating by Type of Content
#Investigate the relationship between rating and content type:

sns.countplot(x='rating', hue='type', data=df)
plt.xticks(rotation=90)
plt.title('Rating by Type of Content (Movie/TV Show)')
plt.show()

# %% [markdown]
# # Content Release Trend Over Time

# %%
df.head(3)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
# 2      s6  TV Show         Midnight Mass    Mike Flanagan  United States
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
# 2  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries

# %%
df['year_added'] = pd.to_datetime(df['date_added']).dt.year

# %%
df.head(3)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
# 2      s6  TV Show         Midnight Mass    Mike Flanagan  United States
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
# 2  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in  year_added
# 0                                      Documentaries        2021
# 1  Crime TV Shows, International TV Shows, TV Act...        2021
# 2                 TV Dramas, TV Horror, TV Mysteries        2021

# %%
#Analyze the trend of content additions over time:
sns.countplot(x='year_added', hue='type', data=df)
plt.title('Content Release Trend Over Time')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Director, Country, and Rating Analysis

# %%
top_directors = df['director'].value_counts()
top_directors
# Out:
# director
# Not Given                         2588
# Rajiv Chilaka                       20
# Alastair Fothergill                 18
# Ra̼l Campos, Jan Suter             18
# Suhas Kadav                         16
#                                   ...
# Matt D'Avella                        1
# Parthiban                            1
# Scott McAboy                         1
# Raymie Muzquiz, Stu Livingston       1
# Mozez Singh                          1
# Name: count, Length: 4528, dtype: int64

# %%
top_directors = df['director'].value_counts().head(10)
top_directors
# Out:
# director
# Not Given                  2588
# Rajiv Chilaka                20
# Alastair Fothergill          18
# Ra̼l Campos, Jan Suter      18
# Suhas Kadav                  16
# Marcus Raboy                 16
# Jay Karas                    14
# Cathy Garcia-Molina          13
# Martin Scorsese              12
# Youssef Chahine              12
# Name: count, dtype: int64

# %%
#Explore the top directors and the type of content they produce:

top_directors = df['director'].value_counts().head(10).index
sns.countplot(x='director', hue='type', data=df[df['director'].isin(top_directors)])
plt.xticks(rotation=90)
plt.title('Top 10 Directors by Type of Content')
plt.show()

# %% [markdown]
# # Content Trend by Year

# %%
#Analyze how the content production (Movies vs. TV Shows) has changed over the years.

#Get the top 20 release years based on content count 
top_20_years= df['release_year'].value_counts().head(20).index

# Create a count plot with 'release_year' on the x-axis and 'type' as the hue 
sns.countplot(x='release_year', hue='type', data=df, order=top_20_years)

# Set the title and rotate x-axis Labels for better readability 
plt.title('Content Production by Year')
plt.xticks (rotation=90)
# Show the plot
plt.tight_layout() 
plt.show()

# %% [markdown]
# # Content Type Over Time

# %%
#Content Type Over Time
#Examine how the types of content available have changed over the years.

plt.figure(figsize=(14, 7))
sns.countplot(x='release_year', hue='type', data=df, palette='Set2', order=sorted(df['release_year'].unique()))

plt.title('Number of Shows by Content Type Over the Years')
plt.xlabel('Release Year')
plt.ylabel('Number of Shows')
plt.xticks(rotation=90)
plt.legend(title='Content Type')
plt.show()

# %%
top_years = df['release_year'].value_counts()
top_years
# Out:
# release_year
# 2018    1146
# 2017    1030
# 2019    1030
# 2020     953
# 2016     901
#         ...
# 1966       1
# 1959       1
# 1925       1
# 1947       1
# 1961       1
# Name: count, Length: 74, dtype: int64

# %%
top_years = df['release_year'].value_counts().head(20).index
top_years
# Out:
# Index([2018, 2017, 2019, 2020, 2016, 2021, 2015, 2014, 2013, 2012, 2010, 2011,
#        2009, 2008, 2006, 2007, 2005, 2004, 2003, 2002],
#       dtype='int64', name='release_year')

# %%
df.head(3)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
# 2      s6  TV Show         Midnight Mass    Mike Flanagan  United States
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
# 2  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in  year_added
# 0                                      Documentaries        2021
# 1  Crime TV Shows, International TV Shows, TV Act...        2021
# 2                 TV Dramas, TV Horror, TV Mysteries        2021

# %% [markdown]
# # Content Rating vs. Release Year

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='release_year', y='rating', hue='type', data=df)

plt.title('Content Rating vs. Release Year')
plt.xlabel('Release Year')
plt.ylabel('Rating')

plt.xticks(rotation=45)
plt.legend(title='Content Type')
plt.show()

# %% [markdown]
# # Distribution of Ratings Over Time

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='release_year', y='rating', hue='type', data=df, marker='o')

plt.title('Average Rating by Release Year')
plt.xlabel('Release Year')
plt.ylabel('Average Rating')

plt.xticks()
plt.legend(title='Content Type')
plt.show()

# %%
# Convert 'date_added' to datetime format
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# Extract month and map to seasons
df['month_added'] = df['date_added'].dt.month
df['season'] = df['month_added'].map({
    1: 'Winter', 2: 'Winter', 3: 'Spring', 4: 'Spring',
    5: 'Spring', 6: 'Summer', 7: 'Summer', 8: 'Summer',
    9: 'Fall', 10: 'Fall', 11: 'Fall', 12: 'Winter'
})

# Plot seasonal trends in content release
plt.figure(figsize=(14, 7))
sns.countplot(x='season', hue='type', data=df, palette='Set2')

plt.title('Seasonal Trends in Content Release')
plt.xlabel('Season')
plt.ylabel('Number of Shows')
plt.show()

# %% [raw]
# Convert date_added to datetime: Ensures the column is in the proper format to extract month information.
#
# Extract month: Get the month from the date_added date.
#
# Map months to seasons: Use a dictionary to map each month to a season.
#
# Plot: Create a count plot to visualize how the number of shows released varies by season and type

# %% [markdown]
# # Number of Shows Added Over Time

# %%
df['month_added'] = df['date_added'].dt.to_period('M')
shows_per_month = df['month_added'].value_counts().sort_index()
shows_per_month
# Out:
# month_added
# 2008-01      1
# 2008-04      1
# 2009-05      1
# 2009-11      1
# 2010-01      1
#           ...
# 2021-08    126
# 2021-09    109
# 2021-10     31
# 2021-11     33
# 2021-12     36
# Freq: M, Name: count, Length: 112, dtype: int64

# %%
shows_per_month.value_counts()
# Out:
# count
# 1      20
# 6       6
# 4       5
# 123     3
# 3       2
#        ..
# 11      1
# 112     1
# 87      1
# 81      1
# 36      1
# Name: count, Length: 68, dtype: int64

# %%
shows_per_month.unique()
# Out:
# array([  1,  11,   4,   2,   3,   6,   7,  13,  14, 170,  18,  19,  15,
#         16,  22,  32,  27,  25,  51, 407,  66,  83,  67,  55,  58,  77,
#         48, 121,  41,  96, 558, 122,  93,  64, 123, 112,  99,  87,  81,
#        149, 536, 147, 133, 157, 103, 117, 110, 115, 153, 200, 464, 134,
#        161, 113, 108, 156, 127, 343, 148, 154, 104, 167, 151, 126, 109,
#         31,  33,  36], dtype=int64)

# %%
plt.figure(figsize=(14, 7))
shows_per_month.plot(kind='line', marker='o', color='b')

plt.title('Number of Shows Added Each Month')
plt.xlabel('Month')
plt.ylabel('Number of Shows')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # conclusion

# %% [raw]
# The analysis of top directors on Netflix, based on the frequency of their contributions and the average ratings of their works, provides valuable insights into the creative landscape of Netflix's offerings. The visualization highlights the following key points:
#
# Prominent Contributors: Directors with a higher number of movies or shows on Netflix tend to dominate the platform in specific genres or styles.
# Diversity in Ratings: Average ratings vary significantly among directors, reflecting the diversity in content quality and audience preferences.
# Insights for Netflix Users and Stakeholders:
# Users: The chart can guide viewers toward directors with consistently high ratings, offering a curated experience.
# Content Creators: Directors can use these insights to gauge audience reception and refine their creative strategies.
# Netflix: Understanding these patterns aids in prioritizing collaborations with high-performing directors.
